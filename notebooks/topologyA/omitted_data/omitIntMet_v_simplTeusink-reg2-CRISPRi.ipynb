# %% [markdown]
# # Set up

# %%
import tellurium as te
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import aesara
import aesara.tensor as at
import pymc as pm

import os
os.getcwd()

from scipy import stats
# Out:
# WARNING (aesara.configdefaults): g++ not available, if using conda: `conda install m2w64-toolchain`
# WARNING (aesara.configdefaults): g++ not detected!  Aesara will be unable to compile C-implementations and will default to Python. Performance may be severely degraded. To remove this warning, set Aesara flags cxx to an empty string.
# WARNING (aesara.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
os.chdir('../..')
from src import BMCA, util
import emll
from emll.aesara_utils import LeastSquaresSolve
os.chdir('notebooks/omitted_data/')

# %%
Teusink_ant ='../../data/interim/Antimony/Simplified_Teusink_reg2.ant'  

r = te.loada(Teusink_ant)
r.conservedMoietyAnalysis = True
r.steadyState()
# Out:
# 1.0077414646998453e-15

# %% [markdown]
# # Leaving out internal species concentrations

# %%
enzymes = ['e_' + i for i in r.getReactionIds()]
internal = r.getFloatingSpeciesIds()
external = r.getBoundarySpeciesIds()
fluxes = ['v_' + i for i in r.getReactionIds()]

# %%
data01 = pd.read_csv('../../data/interim/generated_data/simplTeusink-reg2/Simplified_Teusink_reg2_0.1.csv')[fluxes+external+enzymes]
data02 = pd.read_csv('../../data/interim/generated_data/simplTeusink-reg2/Simplified_Teusink_reg2_0.2.csv')[fluxes+external+enzymes]
data03 = pd.read_csv('../../data/interim/generated_data/simplTeusink-reg2/Simplified_Teusink_reg2_0.3.csv')[fluxes+external+enzymes]
data04 = pd.read_csv('../../data/interim/generated_data/simplTeusink-reg2/Simplified_Teusink_reg2_0.4.csv')[fluxes+external+enzymes]
data05 = pd.read_csv('../../data/interim/generated_data/simplTeusink-reg2/Simplified_Teusink_reg2_0.5.csv')[fluxes+external+enzymes]
data10 = pd.read_csv('../../data/interim/generated_data/simplTeusink-reg2/Simplified_Teusink_reg2_1.01.csv')[fluxes+external+enzymes]

# %%
BMCA_obj01 = BMCA.BMCA(Teusink_ant, data01)
BMCA_obj02= BMCA.BMCA(Teusink_ant, data02)
BMCA_obj03 = BMCA.BMCA(Teusink_ant, data03)
BMCA_obj04 = BMCA.BMCA(Teusink_ant, data04)
BMCA_obj05 = BMCA.BMCA(Teusink_ant, data05)
BMCA_obj10 = BMCA.BMCA(Teusink_ant, data10)
# Out:
# Model does not contain SBML fbc package information.
# ../../data/interim/Antimony/Simplified_Teusink_reg2_cobra.ant
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-23
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vGLK>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vGLK>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPGI>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPGI>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vGLYCO>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vGLYCO>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vTreha>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vTreha>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPFK>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPFK>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vALD>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vALD>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vGAPDH>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vGAPDH>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPGK>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPGK>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPGM>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPGM>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vENO>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vENO>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPYK>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPYK>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPDC>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPDC>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vSUC>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vSUC>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vGLT>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vGLT>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vADH>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vADH>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vG3PDH>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vG3PDH>'
# No objective coefficients in model. Unclear what should be optimized
# Missing flux bounds on reactions set to default bounds.As best practise and to avoid confusion flux bounds should be set explicitly on all reactions.
# Model does not contain SBML fbc package information.
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vGLK>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vGLK>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPGI>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPGI>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vGLYCO>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vGLYCO>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vTreha>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vTreha>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPFK>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPFK>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vALD>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vALD>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vGAPDH>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vGAPDH>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPGK>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPGK>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPGM>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPGM>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vENO>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vENO>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPYK>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPYK>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPDC>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPDC>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vSUC>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vSUC>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vGLT>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vGLT>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vADH>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vADH>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vG3PDH>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vG3PDH>'
# No objective coefficients in model. Unclear what should be optimized
# Missing flux bounds on reactions set to default bounds.As best practise and to avoid confusion flux bounds should be set explicitly on all reactions.
# ../../data/interim/Antimony/Simplified_Teusink_reg2_cobra.ant
# Model does not contain SBML fbc package information.
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vGLK>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vGLK>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPGI>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPGI>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vGLYCO>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vGLYCO>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vTreha>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vTreha>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPFK>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPFK>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vALD>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vALD>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vGAPDH>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vGAPDH>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPGK>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPGK>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPGM>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPGM>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vENO>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vENO>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPYK>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPYK>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPDC>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPDC>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vSUC>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vSUC>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vGLT>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vGLT>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vADH>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vADH>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vG3PDH>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vG3PDH>'
# No objective coefficients in model. Unclear what should be optimized
# Missing flux bounds on reactions set to default bounds.As best practise and to avoid confusion flux bounds should be set explicitly on all reactions.
# ../../data/interim/Antimony/Simplified_Teusink_reg2_cobra.ant
# Model does not contain SBML fbc package information.
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vGLK>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vGLK>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPGI>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPGI>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vGLYCO>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vGLYCO>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vTreha>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vTreha>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPFK>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPFK>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vALD>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vALD>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vGAPDH>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vGAPDH>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPGK>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPGK>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPGM>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPGM>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vENO>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vENO>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPYK>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPYK>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPDC>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPDC>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vSUC>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vSUC>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vGLT>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vGLT>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vADH>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vADH>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vG3PDH>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vG3PDH>'
# No objective coefficients in model. Unclear what should be optimized
# Missing flux bounds on reactions set to default bounds.As best practise and to avoid confusion flux bounds should be set explicitly on all reactions.
# ../../data/interim/Antimony/Simplified_Teusink_reg2_cobra.ant
# Model does not contain SBML fbc package information.
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vGLK>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vGLK>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPGI>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPGI>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vGLYCO>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vGLYCO>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vTreha>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vTreha>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPFK>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPFK>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vALD>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vALD>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vGAPDH>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vGAPDH>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPGK>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPGK>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPGM>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPGM>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vENO>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vENO>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPYK>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPYK>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPDC>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPDC>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vSUC>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vSUC>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vGLT>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vGLT>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vADH>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vADH>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vG3PDH>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vG3PDH>'
# No objective coefficients in model. Unclear what should be optimized
# Missing flux bounds on reactions set to default bounds.As best practise and to avoid confusion flux bounds should be set explicitly on all reactions.
# ../../data/interim/Antimony/Simplified_Teusink_reg2_cobra.ant
# Model does not contain SBML fbc package information.
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vGLK>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vGLK>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPGI>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPGI>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vGLYCO>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vGLYCO>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vTreha>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vTreha>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPFK>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPFK>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vALD>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vALD>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vGAPDH>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vGAPDH>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPGK>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPGK>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPGM>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPGM>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vENO>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vENO>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPYK>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPYK>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vPDC>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vPDC>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vSUC>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vSUC>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vGLT>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vGLT>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vADH>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vADH>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction vG3PDH>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction vG3PDH>'
# No objective coefficients in model. Unclear what should be optimized
# Missing flux bounds on reactions set to default bounds.As best practise and to avoid confusion flux bounds should be set explicitly on all reactions.
# ../../data/interim/Antimony/Simplified_Teusink_reg2_cobra.ant

# %% [markdown]
# ## Running ADVI

# %%
def run_BayesInf(BMCA_obj, n_samp=1):
    known_chi_inds = []
    omitted_chi_inds = []
    for i, sp in enumerate(r.getFloatingSpeciesIds()):
        if sp in data10.columns:
            known_chi_inds.append(i)
        else: 
            omitted_chi_inds.append(i)
    chi_inds = np.hstack([known_chi_inds, omitted_chi_inds]).argsort()
    
    with pm.Model() as pymc_model:
    
        # Initialize elasticities
        Ex_t = pm.Deterministic('Ex', util.initialize_elasticity(BMCA_obj.Ex.to_numpy(), name='Ex'))
        Ey_t = pm.Deterministic('Ey', util.initialize_elasticity(BMCA_obj.Ey.to_numpy(), name='Ey'))

        # trace_prior = pm.sample_prior_predictive(samples=1000)
        
        chi_measured = pm.Normal('chi_measured', mu=0, sigma=0.1, observed=BMCA_obj.xn.T)
        chi_unmeasured = pm.Normal('chi_unmeasured', mu=0, sigma=10, shape=(len(omitted_chi_inds), len(BMCA_obj.xn)))

        chi_t = at.concatenate([chi_measured, chi_unmeasured], axis=0)[chi_inds, :]
        # supposedly chi_t would be in the order listed in ss tellurium

        pm.Deterministic('chi_t', chi_t)

        e_t = pm.Normal('e_t', mu=1, sigma=1, observed=BMCA_obj.en.T) # e_hat?
        y_t = pm.Normal('y_t', mu=0, sigma=10, observed=BMCA_obj.yn.T) # yn?

        likelihood = pm.Deterministic('vn', e_t * (np.ones(BMCA_obj.en.T.shape) + pm.math.dot(Ex_t,chi_t) + pm.math.dot(Ey_t,y_t)))
        v_hat_obs = pm.Normal('v_hat_obs', mu=likelihood, sigma=0.1, observed=BMCA_obj.vn.squeeze().T)

        N_ITERATIONS = 40000

        advi = pm.ADVI()
        tracker = pm.callbacks.Tracker(
            mean = advi.approx.mean.eval,
            std = advi.approx.std.eval
        )
        approx = advi.fit(
            n=N_ITERATIONS, 
            callbacks = [tracker],
            obj_optimizer=pm.adagrad_window(learning_rate=5E-3), 
            total_grad_norm_constraint=0.7,
            obj_n_mc=1)
        
    with sns.plotting_context('notebook', font_scale=1.2):

        fig = plt.figure(figsize=(5,4))
        plt.plot(approx.hist + 30, '.', rasterized=True, ms=1)
        # plt.ylim([-1E1, 1E3])
        plt.xlim([0, N_ITERATIONS])
        sns.despine(trim=True, offset=10)

        plt.ylabel('-ELBO')
        plt.xlabel('Iteration')
        plt.title('in vitro ADVI convergence')
        plt.tight_layout()

    if n_samp > 1:
        samples = []
        for i in range(n_samp): 
            samples.append(approx.sample(draws=1000, random_seed=i))
        return samples
    else:
        return approx.sample(draws=1000, random_seed=n_samp)

# %%
trace01 = run_BayesInf(BMCA_obj01, n_samp=3)
trace02 = run_BayesInf(BMCA_obj02, n_samp=3)
trace03 = run_BayesInf(BMCA_obj03, n_samp=3)
trace04 = run_BayesInf(BMCA_obj04, n_samp=3)
trace05 = run_BayesInf(BMCA_obj05, n_samp=3)
trace10 = run_BayesInf(BMCA_obj10, n_samp=3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='40000' class='' max='40000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [40000/40000 57:37&lt;00:00 Average Loss = 1,886.3]
#     </div>
# c:\Users\user\miniconda3\envs\new_Gayles\lib\site-packages\aesara\scalar\basic.py:2925: RuntimeWarning:
#
# invalid value encountered in log
#
# Finished [100%]: Average Loss = 1,885.5
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='40000' class='' max='40000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [40000/40000 50:59&lt;00:00 Average Loss = 1,710.2]
#     </div>
# c:\Users\user\miniconda3\envs\new_Gayles\lib\site-packages\aesara\scalar\basic.py:2925: RuntimeWarning:
#
# invalid value encountered in log
#
# Finished [100%]: Average Loss = 1,709.8
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='40000' class='' max='40000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [40000/40000 24:25&lt;00:00 Average Loss = 1,583]
#     </div>
# c:\Users\user\miniconda3\envs\new_Gayles\lib\site-packages\aesara\scalar\basic.py:2925: RuntimeWarning:
#
# invalid value encountered in log
#
# Finished [100%]: Average Loss = 1,583.3
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='40000' class='' max='40000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [40000/40000 24:23&lt;00:00 Average Loss = 1,483.5]
#     </div>
# c:\Users\user\miniconda3\envs\new_Gayles\lib\site-packages\aesara\scalar\basic.py:2925: RuntimeWarning:
#
# invalid value encountered in log
#
# Finished [100%]: Average Loss = 1,483.5
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='40000' class='' max='40000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [40000/40000 24:19&lt;00:00 Average Loss = 1,386]
#     </div>
# c:\Users\user\miniconda3\envs\new_Gayles\lib\site-packages\aesara\scalar\basic.py:2925: RuntimeWarning:
#
# invalid value encountered in log
#
# Finished [100%]: Average Loss = 1,386.2
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='40000' class='' max='40000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [40000/40000 24:28&lt;00:00 Average Loss = 1,158.5]
#     </div>
# c:\Users\user\miniconda3\envs\new_Gayles\lib\site-packages\aesara\scalar\basic.py:2925: RuntimeWarning:
#
# invalid value encountered in log
#
# Finished [100%]: Average Loss = 1,158.1

# %% [markdown]
# ### Plotting ADVI results

# %%
Ex01_0 = (trace01[0]['posterior']['Ex']).to_numpy().squeeze()
Ex01_1 = (trace01[1]['posterior']['Ex']).to_numpy().squeeze()
Ex01_2 = (trace01[2]['posterior']['Ex']).to_numpy().squeeze()
Ex01 = np.concatenate([Ex01_0, Ex01_1, Ex01_2])
med_Ex_advi = np.median(Ex01, axis=0)

Ex02_0 = (trace02[0]['posterior']['Ex']).to_numpy().squeeze()
Ex02_1 = (trace02[1]['posterior']['Ex']).to_numpy().squeeze()
Ex02_2 = (trace02[2]['posterior']['Ex']).to_numpy().squeeze()
Ex02 = np.concatenate([Ex02_0, Ex02_1, Ex02_2])
med_Ex_advi = np.median(Ex02, axis=0)

Ex03_0 = (trace03[0]['posterior']['Ex']).to_numpy().squeeze()
Ex03_1 = (trace03[1]['posterior']['Ex']).to_numpy().squeeze()
Ex03_2 = (trace03[2]['posterior']['Ex']).to_numpy().squeeze()
Ex03 = np.concatenate([Ex03_0, Ex03_1, Ex03_2])
med_Ex_advi = np.median(Ex03, axis=0)

Ex04_0 = (trace04[0]['posterior']['Ex']).to_numpy().squeeze()
Ex04_1 = (trace04[1]['posterior']['Ex']).to_numpy().squeeze()
Ex04_2 = (trace04[2]['posterior']['Ex']).to_numpy().squeeze()
Ex04 = np.concatenate([Ex04_0, Ex04_1, Ex04_2])
med_Ex_advi = np.median(Ex04, axis=0)

Ex05_0 = (trace05[0]['posterior']['Ex']).to_numpy().squeeze()
Ex05_1 = (trace05[1]['posterior']['Ex']).to_numpy().squeeze()
Ex05_2 = (trace05[2]['posterior']['Ex']).to_numpy().squeeze()
Ex05 = np.concatenate([Ex05_0, Ex05_1, Ex05_2])
med_Ex_advi = np.median(Ex05, axis=0)

Ex10_0 = (trace10[0]['posterior']['Ex']).to_numpy().squeeze()
Ex10_1 = (trace10[1]['posterior']['Ex']).to_numpy().squeeze()
Ex10_2 = (trace10[2]['posterior']['Ex']).to_numpy().squeeze()
Ex10 = np.concatenate([Ex10_0, Ex10_1, Ex10_2])
med_Ex_advi = np.median(Ex10, axis=0)

# %% [markdown]
# ## Calculating FCCs

# %%
gtFCC = pd.DataFrame(r.getScaledFluxControlCoefficientMatrix(), index=r.getReactionIds(), columns=r.getReactionIds())

# %%
def estimate_CCs(BMCA_obj, Ex):
    BMCA_obj.vn[BMCA_obj.vn == 0] = 1e-6
    
    a = np.diag(BMCA_obj.en.values / BMCA_obj.vn.values)
    a = np.diag(a)
    a = a[np.newaxis,:].repeat(3000, axis=0)

    Ex_ss = a @ Ex
    As = BMCA_obj.N @ np.diag(BMCA_obj.v_star) @ Ex_ss
    bs = BMCA_obj.N @ np.diag(BMCA_obj.v_star)
    bs = bs[np.newaxis, :].repeat(3000, axis=0)
    
    As = at.as_tensor_variable(As)
    bs = at.as_tensor_variable(bs)

    def solve_aesara(A, b):
        rsolve_op = LeastSquaresSolve()
        return rsolve_op(A, b).squeeze()

    CCC, _ = aesara.scan(lambda A, b: solve_aesara(A, b),
                        sequences=[As, bs], strict=True)

    identity = np.eye(len(BMCA_obj.N.T))
    identity = identity[np.newaxis,:].repeat(3000, axis=0)
    
    FCC = (Ex_ss @ CCC.eval()) + identity
    
    return FCC

# %% [markdown]
# ### Negative predictions

# %%
postFCC01 = estimate_CCs(BMCA_obj01, Ex01)
postFCC02 = estimate_CCs(BMCA_obj02, Ex02)
postFCC03 = estimate_CCs(BMCA_obj03, Ex03)
postFCC04 = estimate_CCs(BMCA_obj04, Ex04)
postFCC05 = estimate_CCs(BMCA_obj05, Ex05)
postFCC10 = estimate_CCs(BMCA_obj10, Ex10)

# %%
rxn_FCCs = [postFCC01, postFCC02, postFCC03, postFCC04, postFCC05, postFCC10]
pt_labels = ['0.1x', '0.2x', '0.3x', '0.4x', '0.5x', '1.01x']

# %%
def append_FCC_df(postFCC, label):
    dfs=[]
    
    for idx, rxn in enumerate(r.getReactionIds()):
        # negativity applied here
        df = -pd.DataFrame(postFCC[:,idx,:], columns=r.getReactionIds())
        df['pt_rxn']=[rxn]*len(df)
        dfs.append(df)
    
    w = pd.concat(dfs)
    w['pt_str']=[label]*len(w)
    return w

prd_FCCs = pd.concat([append_FCC_df(rxn_FCCs[i], pt_labels[i]) for i in range(len(rxn_FCCs))])

# %%
medPrdFCCs = pd.pivot_table(prd_FCCs, index=['pt_rxn','pt_str'], aggfunc='median', sort=False)
# medPrdFCCs.loc['vGLK']
medPrdFCCs.head()
# Out:
#                    vGLK      vPGI    vGLYCO    vTreha      vPFK      vALD  \
# pt_rxn pt_str
# vGLK   0.1x   -1.935285 -0.085701  0.015055  0.153899  0.185174 -0.008306
# vPGI   0.1x    0.138960 -2.292308 -0.000228 -0.002335  1.269146 -0.074542
# vGLYCO 0.1x   -0.085948 -0.027005 -1.065118 -0.665653 -0.171184 -0.001701
# vTreha 0.1x   -0.010057 -0.012589 -0.066929 -1.684168 -0.230898  0.026243
# vPFK   0.1x    0.138960 -0.292308 -0.000228 -0.002335 -0.730854 -0.074542
#
#                  vGAPDH      vPGK      vPGM      vENO      vPYK      vPDC  \
# pt_rxn pt_str
# vGLK   0.1x    0.004217 -0.026941 -0.015733  0.012407 -0.024933  0.012069
# vPGI   0.1x    0.097341 -0.058826  0.010386 -0.053246  0.067037 -0.004957
# vGLYCO 0.1x   -0.048932 -0.003779 -0.037991  0.041097 -0.042498  0.012754
# vTreha 0.1x   -0.042940 -0.001354 -0.026903  0.038807 -0.063090  0.017541
# vPFK   0.1x    0.097341 -0.058826  0.010386 -0.053246  0.067037 -0.004957
#
#                    vSUC      vGLT      vADH    vG3PDH
# pt_rxn pt_str
# vGLK   0.1x   -0.001438  0.684699 -0.003857 -0.003363
# vPGI   0.1x    0.000760 -0.120459  0.002037  0.009326
# vGLYCO 0.1x   -0.001088  1.073894 -0.002918 -0.006882
# vTreha 0.1x   -0.003102  1.010090 -0.008318 -0.008298
# vPFK   0.1x    0.000760 -0.120459  0.002037  0.009326

# %% [markdown]
# ### Graphing the averaged differences between ground truth and predicted distributions

# %%
# for each reaction that can be perturbed
for rxn in r.getReactionIds():
    # locate the applicable rows in the medPrdFCCs df
    a = medPrdFCCs.loc[rxn]
    gtvals = np.repeat(gtFCC[rxn].values, repeats=len(pt_labels), axis=0).reshape((len(pt_labels), -1))
    # calculate the absolute difference...
    absDifs = a - gtvals
    # and the relative difference
    relDifs = absDifs/gtvals
    
    # plot both graphs 
    f1 = plt.figure(figsize=(16, 10))
    absDifs.T.plot(kind='bar')
    # alternate color each group of reactions so it is easier to see
    for i in range(8):
            plt.axvspan(2*i + 0.5, 2*i + 1.5, alpha=0.1)
    plt.axhline(0, c='gray')
    plt.ylim((-1,1))
    plt.legend(loc='lower right')
    plt.title(f'ADVI predictions for {rxn} FCCs given all data--absDifs')

    f2 = plt.figure(figsize=(16, 10))
    relDifs.T.plot(kind='bar')
    # alternate color each group of reactions so it is easier to see
    for i in range(8):
            plt.axvspan(2*i + 0.5, 2*i + 1.5, alpha=0.1)
    plt.axhline(0, c='gray')
    plt.ylim((-10,10))
    plt.legend(loc='lower right')
    plt.title(f'ADVI predictions for {rxn} FCCs given all data--relDifs')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20548\3859003407.py:12: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.

# %%
plt.close("all")

# %% [markdown]
# ## Evaluating FCC ranking

# %%
gtFCC=pd.DataFrame(r.getScaledFluxControlCoefficientMatrix(), columns=r.getReactionIds(), index=r.getReactionIds()).abs()
m1 = gtFCC.index.values[:, None] == gtFCC.columns.values
gtFCC = pd.DataFrame(np.select([m1], [float('Nan')], gtFCC), columns=gtFCC.columns, index=gtFCC.index)
gtFCC_rankings= gtFCC.rank(axis=1, ascending=False, na_option='keep')
gtFCC_rankings
# Out:
#         vGLK  vPGI  vGLYCO  vTreha  vPFK  vALD  vGAPDH  vPGK  vPGM  vENO  \
# vGLK     NaN   3.0     4.0     2.0   7.0  13.0    11.0  14.0   5.0   8.0
# vPGI     6.0   NaN    13.0     2.0   5.0  12.0    10.0  14.0   3.0   7.0
# vGLYCO   3.0   4.0     NaN     2.0   7.0  13.0    11.0  14.0   5.0   8.0
# vTreha   2.0   3.0     4.0     NaN   7.0  13.0    11.0  14.0   5.0   8.0
# vPFK     6.0   1.0    13.0     3.0   NaN  12.0    10.0  14.0   4.0   7.0
# vALD     7.0   1.0    13.0     3.0   6.0   NaN    11.0  14.0   4.0   8.0
# vGAPDH   7.0   1.0    14.0     4.0   6.0  13.0     NaN  11.0   3.0   8.0
# vPGK     7.0   1.0    14.0     4.0   6.0  13.0    10.0   NaN   3.0   8.0
# vPGM     6.0   1.0    14.0     3.0   5.0  13.0     9.0  11.0   NaN   7.0
# vENO     7.0   1.0    14.0     4.0   6.0  13.0     9.0  11.0   3.0   NaN
# vPYK     7.0   1.0    14.0     4.0   6.0  13.0     9.0  11.0   3.0   8.0
# vPDC     6.0   1.0    14.0     4.0   5.0  13.0     9.0  11.0   3.0   7.0
# vSUC     8.0   2.0    15.0     5.0   7.0  14.0    11.0  13.0   4.0   9.0
# vGLT     2.0   3.0     4.0     1.0   7.0  13.0    11.0  14.0   5.0   8.0
# vADH     8.0   1.0    15.0     5.0   7.0  14.0    11.0  13.0   4.0   9.0
# vG3PDH   8.0   2.0    13.0     5.0   6.0  12.0     1.0   3.0   9.0  10.0
#
#         vPYK  vPDC  vSUC  vGLT  vADH  vG3PDH
# vGLK     9.0   6.0  15.0   1.0  12.0    10.0
# vPGI     8.0   4.0  15.0   1.0  11.0     9.0
# vGLYCO   9.0   6.0  15.0   1.0  12.0    10.0
# vTreha   9.0   6.0  15.0   1.0  12.0    10.0
# vPFK     8.0   5.0  15.0   2.0  11.0     9.0
# vALD     9.0   5.0  15.0   2.0  12.0    10.0
# vGAPDH   9.0   5.0  15.0   2.0  12.0    10.0
# vPGK     9.0   5.0  15.0   2.0  12.0    11.0
# vPGM     8.0   4.0  15.0   2.0  12.0    10.0
# vENO     8.0   5.0  15.0   2.0  12.0    10.0
# vPYK     NaN   5.0  15.0   2.0  12.0    10.0
# vPDC     8.0   NaN  15.0   2.0  12.0    10.0
# vSUC    10.0   6.0   NaN   3.0   1.0    12.0
# vGLT     9.0   6.0  15.0   NaN  12.0    10.0
# vADH    10.0   6.0   2.0   3.0   NaN    12.0
# vG3PDH  11.0   7.0  15.0   4.0  14.0     NaN

# %%
m1 = gtFCC_rankings.isin([1.0])  
m2 = gtFCC_rankings.isin([2.0])  
m3 = gtFCC_rankings.isin([3.0])  
a = m1.mul(r.getReactionIds()).apply(lambda x: [i for i in x if i], axis=1)
b = m2.mul(r.getReactionIds()).apply(lambda x: [i for i in x if i], axis=1)
c = m3.mul(r.getReactionIds()).apply(lambda x: [i for i in x if i], axis=1)

trueRanks = pd.concat([a,b,c], axis=1)
trueRanks['topThree'] = trueRanks[0] + trueRanks[1] + trueRanks[2]

# %%
rxn_FCCs = [postFCC01, postFCC02, postFCC03, postFCC04, postFCC05, postFCC10]
scores = []
for pt_level in rxn_FCCs:
    postFCC_med=pd.DataFrame(np.median(pt_level, axis=0), columns=r.getReactionIds(), index=r.getReactionIds()).abs()
    # m1 = gtFCC.index.values[:, None] == gtFCC.columns.values
    postFCC_med = pd.DataFrame(np.select([m1], [float('Nan')], postFCC_med), columns=gtFCC.columns, index=gtFCC.index)
    postFCC_med_rankings= postFCC_med.rank(axis=1, ascending=False, na_option='keep')
  
    m1 = postFCC_med_rankings.isin([1.0])  
    m2 = postFCC_med_rankings.isin([2.0])  
    m3 = postFCC_med_rankings.isin([3.0])  
    a = m1.mul(r.getReactionIds()).apply(lambda x: [i for i in x if i], axis=1)
    b = m2.mul(r.getReactionIds()).apply(lambda x: [i for i in x if i], axis=1)
    c = m3.mul(r.getReactionIds()).apply(lambda x: [i for i in x if i], axis=1)

    prdRanks = pd.concat([a,b,c], axis=1)
    prdRanks['topThree'] = prdRanks[0] + prdRanks[1] + prdRanks[2]

    scores.append([len([i for i in prdRanks['topThree'][rxn] if i in trueRanks['topThree'][rxn]]) for rxn in r.getReactionIds()])

topThreeCheckdf = pd.DataFrame(scores, columns=r.getReactionIds(), index=pt_labels).T

# %%
topThreeCheckdf.style.background_gradient(cmap='RdYlBu', axis=None)
# sns.heatmap(topThreeCheckdf, annot=True, cmap='RdYlBu')
# Out:
# <style type="text/css">
# #T_30df8_row0_col0, #T_30df8_row0_col2, #T_30df8_row1_col1, #T_30df8_row1_col3, #T_30df8_row1_col4, #T_30df8_row2_col0, #T_30df8_row2_col4, #T_30df8_row2_col5, #T_30df8_row4_col0, #T_30df8_row4_col1, #T_30df8_row5_col3, #T_30df8_row5_col4, #T_30df8_row6_col1, #T_30df8_row6_col3, #T_30df8_row6_col4, #T_30df8_row7_col1, #T_30df8_row7_col2, #T_30df8_row7_col3, #T_30df8_row7_col4, #T_30df8_row8_col2, #T_30df8_row8_col3, #T_30df8_row9_col1, #T_30df8_row9_col2, #T_30df8_row9_col3, #T_30df8_row9_col4, #T_30df8_row10_col1, #T_30df8_row10_col2, #T_30df8_row10_col4, #T_30df8_row11_col1, #T_30df8_row11_col2, #T_30df8_row11_col3, #T_30df8_row11_col4, #T_30df8_row12_col1, #T_30df8_row12_col5, #T_30df8_row13_col0, #T_30df8_row13_col2, #T_30df8_row14_col1, #T_30df8_row14_col3, #T_30df8_row14_col5, #T_30df8_row15_col0, #T_30df8_row15_col2, #T_30df8_row15_col4, #T_30df8_row15_col5 {
#   background-color: #fdbf71;
#   color: #000000;
# }
# #T_30df8_row0_col1, #T_30df8_row0_col4, #T_30df8_row0_col5, #T_30df8_row1_col2, #T_30df8_row2_col1, #T_30df8_row2_col2, #T_30df8_row2_col3, #T_30df8_row3_col2, #T_30df8_row3_col4, #T_30df8_row3_col5, #T_30df8_row4_col2, #T_30df8_row4_col3, #T_30df8_row5_col2, #T_30df8_row6_col2, #T_30df8_row10_col3, #T_30df8_row12_col3, #T_30df8_row13_col1, #T_30df8_row13_col4, #T_30df8_row13_col5, #T_30df8_row14_col2, #T_30df8_row15_col1, #T_30df8_row15_col3 {
#   background-color: #bde2ee;
#   color: #000000;
# }
# #T_30df8_row0_col3, #T_30df8_row3_col1, #T_30df8_row3_col3, #T_30df8_row13_col3 {
#   background-color: #313695;
#   color: #f1f1f1;
# }
# #T_30df8_row1_col0, #T_30df8_row1_col5, #T_30df8_row3_col0, #T_30df8_row4_col4, #T_30df8_row4_col5, #T_30df8_row5_col0, #T_30df8_row5_col1, #T_30df8_row5_col5, #T_30df8_row6_col0, #T_30df8_row6_col5, #T_30df8_row7_col0, #T_30df8_row7_col5, #T_30df8_row8_col0, #T_30df8_row8_col1, #T_30df8_row8_col4, #T_30df8_row8_col5, #T_30df8_row9_col0, #T_30df8_row9_col5, #T_30df8_row10_col0, #T_30df8_row10_col5, #T_30df8_row11_col0, #T_30df8_row11_col5, #T_30df8_row12_col0, #T_30df8_row12_col2, #T_30df8_row12_col4, #T_30df8_row14_col0, #T_30df8_row14_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_30df8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30df8_level0_col0" class="col_heading level0 col0" >0.1x</th>
#       <th id="T_30df8_level0_col1" class="col_heading level0 col1" >0.2x</th>
#       <th id="T_30df8_level0_col2" class="col_heading level0 col2" >0.3x</th>
#       <th id="T_30df8_level0_col3" class="col_heading level0 col3" >0.4x</th>
#       <th id="T_30df8_level0_col4" class="col_heading level0 col4" >0.5x</th>
#       <th id="T_30df8_level0_col5" class="col_heading level0 col5" >1.01x</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30df8_level0_row0" class="row_heading level0 row0" >vGLK</th>
#       <td id="T_30df8_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_30df8_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_30df8_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_30df8_row0_col3" class="data row0 col3" >3</td>
#       <td id="T_30df8_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_30df8_row0_col5" class="data row0 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_30df8_level0_row1" class="row_heading level0 row1" >vPGI</th>
#       <td id="T_30df8_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_30df8_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_30df8_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_30df8_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_30df8_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_30df8_row1_col5" class="data row1 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_30df8_level0_row2" class="row_heading level0 row2" >vGLYCO</th>
#       <td id="T_30df8_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_30df8_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_30df8_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_30df8_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_30df8_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_30df8_row2_col5" class="data row2 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_30df8_level0_row3" class="row_heading level0 row3" >vTreha</th>
#       <td id="T_30df8_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_30df8_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_30df8_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_30df8_row3_col3" class="data row3 col3" >3</td>
#       <td id="T_30df8_row3_col4" class="data row3 col4" >2</td>
#       <td id="T_30df8_row3_col5" class="data row3 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_30df8_level0_row4" class="row_heading level0 row4" >vPFK</th>
#       <td id="T_30df8_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_30df8_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_30df8_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_30df8_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_30df8_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_30df8_row4_col5" class="data row4 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_30df8_level0_row5" class="row_heading level0 row5" >vALD</th>
#       <td id="T_30df8_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_30df8_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_30df8_row5_col2" class="data row5 col2" >2</td>
#       <td id="T_30df8_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_30df8_row5_col4" class="data row5 col4" >1</td>
#       <td id="T_30df8_row5_col5" class="data row5 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_30df8_level0_row6" class="row_heading level0 row6" >vGAPDH</th>
#       <td id="T_30df8_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_30df8_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_30df8_row6_col2" class="data row6 col2" >2</td>
#       <td id="T_30df8_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_30df8_row6_col4" class="data row6 col4" >1</td>
#       <td id="T_30df8_row6_col5" class="data row6 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_30df8_level0_row7" class="row_heading level0 row7" >vPGK</th>
#       <td id="T_30df8_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_30df8_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_30df8_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_30df8_row7_col3" class="data row7 col3" >1</td>
#       <td id="T_30df8_row7_col4" class="data row7 col4" >1</td>
#       <td id="T_30df8_row7_col5" class="data row7 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_30df8_level0_row8" class="row_heading level0 row8" >vPGM</th>
#       <td id="T_30df8_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_30df8_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_30df8_row8_col2" class="data row8 col2" >1</td>
#       <td id="T_30df8_row8_col3" class="data row8 col3" >1</td>
#       <td id="T_30df8_row8_col4" class="data row8 col4" >0</td>
#       <td id="T_30df8_row8_col5" class="data row8 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_30df8_level0_row9" class="row_heading level0 row9" >vENO</th>
#       <td id="T_30df8_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_30df8_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_30df8_row9_col2" class="data row9 col2" >1</td>
#       <td id="T_30df8_row9_col3" class="data row9 col3" >1</td>
#       <td id="T_30df8_row9_col4" class="data row9 col4" >1</td>
#       <td id="T_30df8_row9_col5" class="data row9 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_30df8_level0_row10" class="row_heading level0 row10" >vPYK</th>
#       <td id="T_30df8_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_30df8_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_30df8_row10_col2" class="data row10 col2" >1</td>
#       <td id="T_30df8_row10_col3" class="data row10 col3" >2</td>
#       <td id="T_30df8_row10_col4" class="data row10 col4"

# %%
topThreeCheckdf.sum(axis=0)
# Out:
# 0.1x      5
# 0.2x     20
# 0.3x     22
# 0.4x     27
# 0.5x     15
# 1.01x    10
# dtype: int64
