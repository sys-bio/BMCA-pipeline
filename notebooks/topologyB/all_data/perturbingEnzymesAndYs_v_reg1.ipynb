# %% [markdown]
# # Set up

# %%
import tellurium as te
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import aesara.tensor as at
import aesara
floatX = aesara.config.floatX
import pymc as pm
import numpy as np

import cobra
import os

from scipy import stats
import scipy as sp

print(os.getcwd())
# Out:
# WARNING (aesara.configdefaults): g++ not available, if using conda: `conda install m2w64-toolchain`
# WARNING (aesara.configdefaults): g++ not detected!  Aesara will be unable to compile C-implementations and will default to Python. Performance may be severely degraded. To remove this warning, set Aesara flags cxx to an empty string.
# WARNING (aesara.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# c:\Users\user\Documents\research\BMCA-pipeline\notebooks\topologyB\all_data

# %%
os.chdir('../../..')
from src import BMCA, util
import emll
from emll.aesara_utils import LeastSquaresSolve
os.chdir('notebooks/topologyB/all_data/')

# %% [markdown]
# # Perturbing enzymes

# %% [raw]
# # generate enzyme perturbation data
# ant ='../../../data/interim/Antimony/JSexample22_reg1.ant'
# util.generate_data(ant, [10], '../../../data/interim/generated_data/JSexample22-reg1/')

# %% [raw]
# s = te.loada('../../data/interim/Antimony/Simplified_Teusink_reg1.ant')
# with open('../../data/interim/sbml/Simplified_Teusink_reg1_cobra.xml', 'w') as f:
#     f.write(s.getCurrentSBML())

# %%
ant ='../../../data/interim/Antimony/JSexample22_reg1.ant'  

data_file1 = '../../../data/interim/generated_data/JSexample22-reg1/JSexample22_reg1_1.01.csv'
data_file15 = '../../../data/interim/generated_data/JSexample22-reg1/JSexample22_reg1_1.5.csv'
data_file3 = '../../../data/interim/generated_data/JSexample22-reg1/JSexample22_reg1_3.csv'
data_file5 = '../../../data/interim/generated_data/JSexample22-reg1/JSexample22_reg1_5.csv'
data_file7 = '../../../data/interim/generated_data/JSexample22-reg1/JSexample22_reg1_7.csv'
data_file10 = '../../../data/interim/generated_data/JSexample22-reg1/JSexample22_reg1_10.csv'

r = te.loada(ant)
r.conservedMoietyAnalysis = True
r.steadyState()

# data_files = [data_file05, data_file10, data_file15, data_file3, data_file5, data_file7, data_file100]
# Out:
# 1.2627690741056199e-15

# %%
BMCA_obj1 = BMCA.BMCA(ant, data_file1)
BMCA_obj15 = BMCA.BMCA(ant, data_file15)
BMCA_obj3 = BMCA.BMCA(ant, data_file3)
BMCA_obj5 = BMCA.BMCA(ant, data_file5)
BMCA_obj7 = BMCA.BMCA(ant, data_file7)
BMCA_obj10 = BMCA.BMCA(ant, data_file10)
# Out:
# Model does not contain SBML fbc package information.
# ../../../data/interim/Antimony/JSexample22_reg1_cobra.ant
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-23
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v2>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v2>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v3>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v3>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v13>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v13>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v4>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v4>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v5>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v5>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v6>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v6>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v7>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v7>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v8>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v8>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v9>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v9>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v10>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v10>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v11>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v11>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v12>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v12>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v14>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v14>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v15>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v15>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v16>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v16>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v17>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v17>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v18>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v18>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v19>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v19>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v21>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v21>'
# No objective coefficients in model. Unclear what should be optimized
# Missing flux bounds on reactions set to default bounds.As best practise and to avoid confusion flux bounds should be set explicitly on all reactions.
# Model does not contain SBML fbc package information.
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v2>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v2>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v3>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v3>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v13>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v13>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v4>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v4>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v5>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v5>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v6>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v6>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v7>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v7>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v8>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v8>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v9>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v9>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v10>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v10>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v11>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v11>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v12>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v12>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v14>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v14>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v15>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v15>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v16>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v16>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v17>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v17>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v18>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v18>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v19>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v19>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v21>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v21>'
# No objective coefficients in model. Unclear what should be optimized
# Missing flux bounds on reactions set to default bounds.As best practise and to avoid confusion flux bounds should be set explicitly on all reactions.
# ../../../data/interim/Antimony/JSexample22_reg1_cobra.ant
# Model does not contain SBML fbc package information.
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v2>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v2>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v3>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v3>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v13>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v13>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v4>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v4>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v5>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v5>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v6>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v6>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v7>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v7>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v8>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v8>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v9>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v9>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v10>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v10>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v11>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v11>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v12>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v12>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v14>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v14>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v15>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v15>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v16>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v16>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v17>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v17>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v18>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v18>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v19>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v19>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v21>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v21>'
# No objective coefficients in model. Unclear what should be optimized
# Missing flux bounds on reactions set to default bounds.As best practise and to avoid confusion flux bounds should be set explicitly on all reactions.
# ../../../data/interim/Antimony/JSexample22_reg1_cobra.ant
# Model does not contain SBML fbc package information.
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v2>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v2>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v3>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v3>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v13>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v13>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v4>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v4>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v5>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v5>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v6>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v6>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v7>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v7>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v8>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v8>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v9>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v9>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v10>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v10>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v11>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v11>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v12>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v12>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v14>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v14>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v15>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v15>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v16>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v16>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v17>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v17>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v18>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v18>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v19>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v19>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v21>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v21>'
# No objective coefficients in model. Unclear what should be optimized
# Missing flux bounds on reactions set to default bounds.As best practise and to avoid confusion flux bounds should be set explicitly on all reactions.
# ../../../data/interim/Antimony/JSexample22_reg1_cobra.ant
# Model does not contain SBML fbc package information.
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v2>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v2>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v3>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v3>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v13>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v13>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v4>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v4>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v5>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v5>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v6>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v6>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v7>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v7>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v8>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v8>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v9>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v9>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v10>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v10>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v11>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v11>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v12>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v12>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v14>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v14>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v15>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v15>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v16>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v16>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v17>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v17>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v18>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v18>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v19>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v19>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v21>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v21>'
# No objective coefficients in model. Unclear what should be optimized
# Missing flux bounds on reactions set to default bounds.As best practise and to avoid confusion flux bounds should be set explicitly on all reactions.
# ../../../data/interim/Antimony/JSexample22_reg1_cobra.ant
# Model does not contain SBML fbc package information.
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v2>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v2>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v3>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v3>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v13>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v13>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v4>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v4>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v5>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v5>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v6>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v6>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v7>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v7>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v8>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v8>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v9>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v9>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v10>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v10>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v11>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v11>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v12>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v12>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v14>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v14>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v15>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v15>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v16>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v16>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v17>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v17>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v18>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v18>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v19>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v19>'
# Missing lower flux bound set to '-1000.0' for reaction: '<Reaction v21>'
# Missing upper flux bound set to '1000.0' for reaction: '<Reaction v21>'
# No objective coefficients in model. Unclear what should be optimized
# Missing flux bounds on reactions set to default bounds.As best practise and to avoid confusion flux bounds should be set explicitly on all reactions.
# ../../../data/interim/Antimony/JSexample22_reg1_cobra.ant

# %%
def run_ADVI(BMCA_obj):
    with pm.Model() as pymc_model:
        
        # Initialize elasticities
        Ex_t = pm.Deterministic('Ex', util.initialize_elasticity(BMCA_obj.Ex.to_numpy(), name='Ex'))
        Ey_t = pm.Deterministic('Ey', util.initialize_elasticity(BMCA_obj.Ey.to_numpy(), name='Ey'))
        e_obs = pm.Normal('e_obs', mu=1, sigma=1, observed=BMCA_obj.en.T)
        chi_obs = pm.Normal('chi_obs', mu=0, sigma=10, observed=BMCA_obj.xn.T)
        y_obs = pm.Normal('y_obs', mu=0, sigma=10, observed=BMCA_obj.yn.T)
        likelihood = pm.Deterministic('vn', e_obs * (np.ones(BMCA_obj.en.T.shape) + pm.math.dot(Ex_t,chi_obs) + pm.math.dot(Ey_t,y_obs)))
        v_hat_obs = pm.Normal('v_hat_obs', mu=likelihood, sigma=0.1, observed=BMCA_obj.vn.squeeze().T)
    
        N_ITERATIONS = 2# 45000
    
    with pymc_model:
        advi = pm.ADVI()
        tracker = pm.callbacks.Tracker(
            mean = advi.approx.mean.eval,
            std = advi.approx.std.eval
        )
        approx = advi.fit(
            n=       N_ITERATIONS, 
            callbacks = [tracker],
            obj_optimizer=pm.adagrad_window(learning_rate=5E-3), 
            total_grad_norm_constraint=0.7,
            obj_n_mc=1)
    
    with sns.plotting_context('notebook', font_scale=1.2):

        fig = plt.figure(figsize=(5,4))
        plt.plot(approx.hist + 30, '.', rasterized=True, ms=1)
        # plt.ylim([-1E1, 1E3])
        plt.xlim([0, N_ITERATIONS])
        sns.despine(trim=True, offset=10)

        plt.ylabel('-ELBO')
        plt.xlabel('Iteration')
        plt.title('in vitro ADVI convergence')
        plt.tight_layout()

    return approx.sample(draws=1000, random_seed=1)

# %%
trace1 = run_ADVI(BMCA_obj1)
trace15 = run_ADVI(BMCA_obj15)
trace3 = run_ADVI(BMCA_obj3)
trace5 = run_ADVI(BMCA_obj5)
trace7 = run_ADVI(BMCA_obj7)
trace10 = run_ADVI(BMCA_obj10)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2/2 00:00&lt;00:00 Average Loss = 15,857]
#     </div>
# c:\Users\user\miniconda3\envs\new_Gayles\lib\site-packages\aesara\scalar\basic.py:2925: RuntimeWarning:
#
# invalid value encountered in log
#
# Finished [100%]: Loss = 16,064
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2/2 00:00&lt;00:00 Average Loss = 20,474]
#     </div>
# c:\Users\user\miniconda3\envs\new_Gayles\lib\site-packages\aesara\scalar\basic.py:2925: RuntimeWarning:
#
# invalid value encountered in log
#
# Finished [100%]: Loss = 19,670
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2/2 00:00&lt;00:00 Average Loss = 60,008]
#     </div>
# c:\Users\user\miniconda3\envs\new_Gayles\lib\site-packages\aesara\scalar\basic.py:2925: RuntimeWarning:
#
# invalid value encountered in log
#
# Finished [100%]: Loss = 43,116
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2/2 00:00&lt;00:00 Average Loss = 50,030]
#     </div>
# c:\Users\user\miniconda3\envs\new_Gayles\lib\site-packages\aesara\scalar\basic.py:2925: RuntimeWarning:
#
# invalid value encountered in log
#
# Finished [100%]: Loss = 96,123
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2/2 00:00&lt;00:00 Average Loss = 1.1221e+05]
#     </div>
# c:\Users\user\miniconda3\envs\new_Gayles\lib\site-packages\aesara\scalar\basic.py:2925: RuntimeWarning:
#
# invalid value encountered in log
#
# Finished [100%]: Loss = 1.444e+05
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2/2 00:00&lt;00:00 Average Loss = 6.3064e+05]
#     </div>
# c:\Users\user\miniconda3\envs\new_Gayles\lib\site-packages\aesara\scalar\basic.py:2925: RuntimeWarning:
#
# invalid value encountered in log
#
# Finished [100%]: Loss = 4.9591e+05

# %%
ExTrace_1 = (trace1['posterior']['Ex']).to_numpy().squeeze()
ExTrace_15 = (trace15['posterior']['Ex']).to_numpy().squeeze()
ExTrace_3 = (trace3['posterior']['Ex']).to_numpy().squeeze()
ExTrace_5 = (trace5['posterior']['Ex']).to_numpy().squeeze()
ExTrace_7 = (trace7['posterior']['Ex']).to_numpy().squeeze()
ExTrace_10 = (trace10['posterior']['Ex']).to_numpy().squeeze()

# %%
medEx_1 = np.median(ExTrace_1, axis=0)
medEx_15 = np.median(ExTrace_15, axis=0)
medEx_3 = np.median(ExTrace_3, axis=0)
medEx_5 = np.median(ExTrace_5, axis=0)
medEx_7 = np.median(ExTrace_7, axis=0)
medEx_10 = np.median(ExTrace_10, axis=0)
medExs = [medEx_1, medEx_15, medEx_3, medEx_5, medEx_7, medEx_10]

# %% [markdown]
# ## Elasticity comparisons

# %%
gt = pd.DataFrame(r.getScaledElasticityMatrix(), index=r.getReactionIds(), columns=r.getFloatingSpeciesIds())
gt['pt'] = ['gt']* len(gt)
gt.index.name = 'reactions'
gt.reset_index(inplace=True)
gt.set_index(['pt', 'reactions'], inplace=True)
medEx_pile = [gt]

pt_labels = ['1.01x', '1.5x', '3x', '5x', '7x', '10x']
for i, lvl in enumerate(pt_labels):
    mdEx = pd.DataFrame(medExs[i], index=r.getReactionIds(), columns=r.getFloatingSpeciesIds())  
    mdEx_by_pt = pd.concat([mdEx], keys=[lvl], names=['perturbation'])
    medEx_pile.append(mdEx_by_pt)
medEx_df = pd.concat(medEx_pile)
# medEx_df.to_csv('kataraTEST.csv')

# %% [markdown]
# ## Calculating FCCs

# %%
gtFCC = pd.DataFrame(r.getScaledFluxControlCoefficientMatrix(), index=r.getReactionIds(), columns=r.getReactionIds())

# we are trying to add the ground truth to the larger
# df of FCC predictions
gtFCC.index.name = 'reactions'
gtFCC.reset_index(inplace=True)
gtFCC['pt']=['gt']*len(gtFCC)
gtFCC.set_index(['pt', 'reactions'], inplace=True)

gtFCC
# Out:
#                     v2        v3       v13        v4        v5        v6  \
# pt reactions
# gt v2         0.315317  0.008758  0.170775  0.130267  0.140743  0.008211
#    v3         0.080340  0.047757  0.931177 -0.015285 -0.016515 -0.000964
#    v13        0.080340  0.047757  0.931177 -0.015285 -0.016515 -0.000964
#    v4         0.398830 -0.005102 -0.099477  0.181997  0.196633  0.011472
#    v5         0.398830 -0.005102 -0.099477  0.181997  0.196633  0.011472
#    v6         0.275401 -0.003523 -0.068691  0.125673  0.135780  0.043492
#    v7         0.275401 -0.003523 -0.068691  0.125673  0.135780  0.043492
#    v8         0.928394 -0.011876 -0.231561  0.423651  0.457722 -0.054932
#    v9         0.547152 -0.006999 -0.136471  0.249680  0.269760 -0.032374
#    v10        0.547152 -0.006999 -0.136471  0.249680  0.269760 -0.032374
#    v11        0.547152 -0.006999 -0.136471  0.249680  0.269760 -0.032374
#    v12        0.547152 -0.006999 -0.136471  0.249680  0.269760 -0.032374
#    v14        1.029505 -0.013169 -0.256781  0.469790  0.507572 -0.060914
#    v15        0.844374 -0.010801 -0.210605  0.385311  0.416298 -0.049961
#    v16        0.844374 -0.010801 -0.210605  0.385311  0.416298 -0.049961
#    v17        0.844374 -0.010801 -0.210605  0.385311  0.416298 -0.049961
#    v18        0.844374 -0.010801 -0.210605  0.385311  0.416298 -0.049961
#    v19        0.550919 -0.007047 -0.137411  0.251399  0.271617 -0.032597
#    v21       -0.041428  0.000530  0.010333 -0.018905 -0.020425  0.002451
#
#                     v7        v8        v9       v10       v11       v12  \
# pt reactions
# gt v2         0.129132  0.000991 -0.007753 -0.002215  0.026180  0.073777
#    v3        -0.015152 -0.000116  0.000910  0.000260 -0.003072 -0.008657
#    v13       -0.015152 -0.000116  0.000910  0.000260 -0.003072 -0.008657
#    v4         0.180412  0.001384 -0.010831 -0.003094  0.036576  0.103074
#    v5         0.180412  0.001384 -0.010831 -0.003094  0.036576  0.103074
#    v6         0.683956 -0.001966 -0.106778 -0.030502 -0.010817 -0.030483
#    v7         0.683956 -0.001966 -0.106778 -0.030502 -0.010817 -0.030483
#    v8        -0.863858  0.138910 -0.359954 -0.102825 -0.036464 -0.102759
#    v9        -0.509117 -0.003906  0.162014  0.046281  0.114433  0.322481
#    v10       -0.509117 -0.003906  0.162014  0.046281  0.114433  0.322481
#    v11       -0.509117 -0.003906  0.162014  0.046281  0.114433  0.322481
#    v12       -0.509117 -0.003906  0.162014  0.046281  0.114433  0.322481
#    v14       -0.957940  0.154038 -0.399157 -0.114024 -0.040435 -0.113950
#    v15       -0.785679  0.126338 -0.327379 -0.093519 -0.033164 -0.093459
#    v16       -0.785679  0.126338 -0.327379 -0.093519 -0.033164 -0.093459
#    v17       -0.785679  0.126338 -0.327379 -0.093519 -0.033164 -0.093459
#    v18       -0.785679  0.126338 -0.327379 -0.093519 -0.033164 -0.093459
#    v19       -0.512622  0.082430 -0.213601 -0.061017 -0.021638 -0.060978
#    v21        0.038548 -0.006199  0.016062  0.004588  0.001627  0.004585
#
#                    v14       v15       v16       v17       v18       v19  \
# pt reactions
# gt v2         0.002640  0.002720  0.000183  0.000121  0.000047  0.000159
#    v3        -0.000310 -0.000319 -0.000021 -0.000014 -0.000005 -0.000019
#    v13       -0.000310 -0.000319 -0.000021 -0.000014 -0.000005 -0.000019
#    v4         0.003688  0.003800  0.000255  0.000169  0.000065  0.000222
#    v5         0.003688  0.003800  0.000255  0.000169  0.000065  0.000222
#    v6        -0.005238 -0.005398 -0.000363 -0.000240 -0.000093 -0.000315
#    v7        -0.005238 -0.005398 -0.000363 -0.000240 -0.000093 -0.000315
#    v8         0.370131  0.381401  0.025614  0.016960  0.006570  0.022247
#    v9        -0.010407 -0.010724 -0.000720 -0.000477 -0.000185 -0.000626
#    v10       -0.010407 -0.010724 -0.000720 -0.000477 -0.000185 -0.000626
#    v11       -0.010407 -0.010724 -0.000720 -0.000477 -0.000185 -0.000626
#    v12       -0.010407 -0.010724 -0.000720 -0.000477 -0.000185 -0.000626
#    v14        0.907173 -0.095653 -0.006424 -0.004254 -0.001648 -0.005579
#    v15       -0.076134  0.777817  0.052236  0.034588  0.013399  0.045369
#    v16       -0.076134  0.777817  0.052236  0.034588  0.013399  0.045369
#    v17       -0.076134  0.777817  0.052236  0.034588  0.013399  0.045369
#    v18       -0.076134  0.777817  0.052236  0.034588  0.013399  0.045369
#    v19       -0.049674  0.507493  0.034082  0.022567  0.008742  0.053908
#    v21        0.003735 -0.038163 -0.002563 -0.001697 -0.000657  0.071144
#
#                    v21
# pt reactions
# gt v2        -0.000053
#    v3         0.000006
#    v13        0.000006
#    v4        -0.000073
#    v5        -0.000073
#    v6         0.000104
#    v7         0.000104
#    v8        -0.007370
#    v9         0.000207
#    v10        0.000207
#    v11        0.000207
#    v12        0.000207
#    v14        0.001848
#    v15       -0.015030
#    v16       -0.015030
#    v17       -0.015030
#    v18       -0.015030
#    v19        0.313429
#    v21        0.976431

# %%
def estimate_CCs(BMCA_obj, Ex):
    BMCA_obj.vn[BMCA_obj.vn == 0] = 1e-6
    
    a = np.diag(BMCA_obj.en.values / BMCA_obj.vn.values)
    a = np.diag(a)
    a = a[np.newaxis,:].repeat(1000, axis=0)

    Ex_ss = a @ Ex
    As = BMCA_obj.N @ np.diag(BMCA_obj.v_star) @ Ex_ss
    bs = BMCA_obj.N @ np.diag(BMCA_obj.v_star)
    bs = bs[np.newaxis, :].repeat(1000, axis=0)
    
    As = at.as_tensor_variable(As)
    bs = at.as_tensor_variable(bs)

    def solve_aesara(A, b):
        rsolve_op = LeastSquaresSolve()
        return rsolve_op(A, b).squeeze()

    CCC, _ = aesara.scan(lambda A, b: solve_aesara(A, b),
                        sequences=[As, bs], strict=True)

    identity = np.eye(len(BMCA_obj.N.T))
    identity = identity[np.newaxis,:].repeat(1000, axis=0)
    
    FCC = (Ex_ss @ CCC.eval()) + identity
    
    # return CCC.eval(), FCC
    return FCC

# %% [markdown]
# ### Negative predictions

# %%
postFCC1 = estimate_CCs(BMCA_obj1, ExTrace_1)
postFCC15 = estimate_CCs(BMCA_obj15, ExTrace_15)
postFCC3 = estimate_CCs(BMCA_obj3, ExTrace_3)
postFCC5 = estimate_CCs(BMCA_obj5, ExTrace_5)
postFCC7 = estimate_CCs(BMCA_obj7, ExTrace_7)
postFCC10 = estimate_CCs(BMCA_obj10, ExTrace_10)

# %%
rxn_FCCs = [postFCC1, postFCC15, postFCC3, postFCC5, postFCC7, postFCC10]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [16], line 6
#       4 gtFCC.reset_index(inplace=True)
#       5 gtFCC['pt_lvl']=['gt']*len(gtFCC)
# ----> 6 gtFCC.set_index(['pt', 'reactions'], inplace=True)
#
# File c:\Users\user\miniconda3\envs\new_Gayles\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\user\miniconda3\envs\new_Gayles\lib\site-packages\pandas\core\frame.py:6001, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5998                 missing.append(col)
#    6000 if missing:
# -> 6001     raise KeyError(f"None of {missing} are in the columns")
#    6003 if inplace:
#    6004     frame = self
#
# KeyError: "None of ['pt', 'reactions'] are in the columns"

# %%
gtFCC.set_index(['pt', 'reactions'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 gtFCC.set_index(['pt', 'reactions'], inplace=True)
#
# File c:\Users\user\miniconda3\envs\new_Gayles\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\user\miniconda3\envs\new_Gayles\lib\site-packages\pandas\core\frame.py:6001, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5998                 missing.append(col)
#    6000 if missing:
# -> 6001     raise KeyError(f"None of {missing} are in the columns")
#    6003 if inplace:
#    6004     frame = self
#
# KeyError: "None of ['pt', 'reactions'] are in the columns"

# %%
medPrdFCCs.head()
# Out:
#                      v2        v3       v13        v4        v5        v6  \
# pt_str pt_rxn
# 1.01x  v2     -1.903318  0.152919  0.077263  0.099908  0.086784  0.157271
#        v3      0.110643 -1.393291  0.360486  0.006010 -0.076160 -0.000489
#        v13     0.110643  0.606709 -1.639514  0.006010 -0.076160 -0.000489
#        v4      0.090729 -0.004868 -0.013117 -1.881692  0.141036  0.190079
#        v5      0.090729 -0.004868 -0.013117  0.118308 -1.858964  0.190079
#
#                      v7        v8        v9       v10       v11       v12  \
# pt_str pt_rxn
# 1.01x  v2      0.124241 -0.000141  0.062143  0.045109  0.044764  0.042598
#        v3      0.020149 -0.014346  0.002840  0.015338 -0.008926  0.017538
#        v13     0.020149 -0.014346  0.002840  0.015338 -0.008926  0.017538
#        v4      0.177761  0.009017  0.077910  0.050439  0.064182  0.060717
#        v5      0.177761  0.009017  0.077910  0.050439  0.064182  0.060717
#
#                     v14       v15       v16       v17       v18       v19  \
# pt_str pt_rxn
# 1.01x  v2      0.007601  0.021335 -0.003520  0.000669 -0.014164  0.018157
#        v3      0.003722  0.018706 -0.007965 -0.013854 -0.026036 -0.018641
#        v13     0.003722  0.018706 -0.007965 -0.013854 -0.026036 -0.018641
#        v4      0.003356  0.005334 -0.003639 -0.002332 -0.011887 -0.002739
#        v5      0.003356  0.005334 -0.003639 -0.002332 -0.011887 -0.002739
#
#                     v21
# pt_str pt_rxn
# 1.01x  v2     -0.006015
#        v3      0.006176
#        v13     0.006176
#        v4      0.000907
#        v5      0.000907

# %%
def append_FCC_df(postFCC, label):
    dfs=[]
    
    for idx, rxn in enumerate(r.getReactionIds()):
        # negativity applied here
        df = -pd.DataFrame(postFCC[:,idx,:], columns=r.getReactionIds())
        df['pt_rxn']=[rxn]*len(df)
        dfs.append(df)
    
    w = pd.concat(dfs)
    w['pt_str']=[label]*len(w)
    return w

prd_FCCs = pd.concat([append_FCC_df(rxn_FCCs[i], pt_labels[i]) for i in range(len(rxn_FCCs))])

# %%
medPrdFCCs = pd.pivot_table(prd_FCCs, index=['pt_str', 'pt_rxn'], aggfunc='median', sort=False)
# medPrdFCCs.loc['vGLK']
medPrdFCCs.head()
# Out:
#                      v2        v3       v13        v4        v5        v6  \
# pt_str pt_rxn
# 1.01x  v2     -1.903318  0.152919  0.077263  0.099908  0.086784  0.157271
#        v3      0.110643 -1.393291  0.360486  0.006010 -0.076160 -0.000489
#        v13     0.110643  0.606709 -1.639514  0.006010 -0.076160 -0.000489
#        v4      0.090729 -0.004868 -0.013117 -1.881692  0.141036  0.190079
#        v5      0.090729 -0.004868 -0.013117  0.118308 -1.858964  0.190079
#
#                      v7        v8        v9       v10       v11       v12  \
# pt_str pt_rxn
# 1.01x  v2      0.124241 -0.000141  0.062143  0.045109  0.044764  0.042598
#        v3      0.020149 -0.014346  0.002840  0.015338 -0.008926  0.017538
#        v13     0.020149 -0.014346  0.002840  0.015338 -0.008926  0.017538
#        v4      0.177761  0.009017  0.077910  0.050439  0.064182  0.060717
#        v5      0.177761  0.009017  0.077910  0.050439  0.064182  0.060717
#
#                     v14       v15       v16       v17       v18       v19  \
# pt_str pt_rxn
# 1.01x  v2      0.007601  0.021335 -0.003520  0.000669 -0.014164  0.018157
#        v3      0.003722  0.018706 -0.007965 -0.013854 -0.026036 -0.018641
#        v13     0.003722  0.018706 -0.007965 -0.013854 -0.026036 -0.018641
#        v4      0.003356  0.005334 -0.003639 -0.002332 -0.011887 -0.002739
#        v5      0.003356  0.005334 -0.003639 -0.002332 -0.011887 -0.002739
#
#                     v21
# pt_str pt_rxn
# 1.01x  v2     -0.006015
#        v3      0.006176
#        v13     0.006176
#        v4      0.000907
#        v5      0.000907

# %% [markdown]
# ### Graphing the averaged differences between ground truth and predicted distributions

# %%
# for each reaction that can be perturbed
for rxn in r.getReactionIds():
    # locate the applicable rows in the medPrdFCCs df
    a = medPrdFCCs.loc[rxn]
    gtvals = np.repeat(gtFCC[rxn].values, repeats=len(pt_labels), axis=0).reshape((len(pt_labels), -1))
    # calculate the absolute difference...
    absDifs = a - gtvals
    # and the relative difference
    relDifs = absDifs/gtvals
    
    # plot both graphs 
    f1 = plt.figure(figsize=(16, 10))
    absDifs.T.plot(kind='bar')
    # alternate color each group of reactions so it is easier to see
    for i in range(8):
            plt.axvspan(2*i + 0.5, 2*i + 1.5, alpha=0.1)
    plt.axhline(0, c='gray')
    plt.ylim((-1,1))
    plt.legend(loc='lower right')
    plt.title(f'ADVI predictions for {rxn} FCCs given all data--absDifs')

    f2 = plt.figure(figsize=(16, 10))
    relDifs.T.plot(kind='bar')
    # alternate color each group of reactions so it is easier to see
    for i in range(8):
            plt.axvspan(2*i + 0.5, 2*i + 1.5, alpha=0.1)
    plt.axhline(0, c='gray')
    plt.ylim((-10,10))
    plt.legend(loc='lower right')
    plt.title(f'ADVI predictions for {rxn} FCCs given all data--relDifs')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7172\3859003407.py:12: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.

# %%
plt.close("all")

# %% [markdown]
# ## Evaluating FCC ranking

# %%
gtFCC=pd.DataFrame(r.getScaledFluxControlCoefficientMatrix(), columns=r.getReactionIds(), index=r.getReactionIds()).abs()
m1 = gtFCC.index.values[:, None] == gtFCC.columns.values
gtFCC = pd.DataFrame(np.select([m1], [float('Nan')], gtFCC), columns=gtFCC.columns, index=gtFCC.index)
gtFCC_rankings= gtFCC.rank(axis=1, ascending=False, na_option='keep')
# gtFCC_rankings

# %%
m1 = gtFCC_rankings.isin([1.0])  
m2 = gtFCC_rankings.isin([2.0])  
m3 = gtFCC_rankings.isin([3.0])  
a = m1.mul(r.getReactionIds()).apply(lambda x: [i for i in x if i], axis=1)
b = m2.mul(r.getReactionIds()).apply(lambda x: [i for i in x if i], axis=1)
c = m3.mul(r.getReactionIds()).apply(lambda x: [i for i in x if i], axis=1)

trueRanks = pd.concat([a,b,c], axis=1)
trueRanks['topThree'] = trueRanks[0] + trueRanks[1] + trueRanks[2]

# %%
rxn_FCCs = [postFCC1, postFCC15, postFCC3, postFCC5, postFCC7, postFCC10]
scores = []
for pt_level in rxn_FCCs:
    postFCC_med=pd.DataFrame(np.median(pt_level, axis=0), columns=r.getReactionIds(), index=r.getReactionIds()).abs()
    # m1 = gtFCC.index.values[:, None] == gtFCC.columns.values
    postFCC_med = pd.DataFrame(np.select([m1], [float('Nan')], postFCC_med), columns=gtFCC.columns, index=gtFCC.index)
    postFCC_med_rankings= postFCC_med.rank(axis=1, ascending=False, na_option='keep')
  
    m1 = postFCC_med_rankings.isin([1.0])  
    m2 = postFCC_med_rankings.isin([2.0])  
    m3 = postFCC_med_rankings.isin([3.0])  
    a = m1.mul(r.getReactionIds()).apply(lambda x: [i for i in x if i], axis=1)
    b = m2.mul(r.getReactionIds()).apply(lambda x: [i for i in x if i], axis=1)
    c = m3.mul(r.getReactionIds()).apply(lambda x: [i for i in x if i], axis=1)

    prdRanks = pd.concat([a,b,c], axis=1)
    prdRanks['topThree'] = prdRanks[0] + prdRanks[1] + prdRanks[2]

    scores.append([len([i for i in prdRanks['topThree'][rxn] if i in trueRanks['topThree'][rxn]]) for rxn in r.getReactionIds()])

topThreeCheckdf = pd.DataFrame(scores, columns=r.getReactionIds(), index=pt_labels).T

# %%
topThreeCheckdf.style.background_gradient(cmap='RdYlBu', axis=None)
# sns.heatmap(topThreeCheckdf, annot=True, cmap='RdYlBu')
# Out:
# <style type="text/css">
# #T_d0d42_row0_col0, #T_d0d42_row0_col4, #T_d0d42_row7_col1, #T_d0d42_row7_col2, #T_d0d42_row7_col3, #T_d0d42_row7_col4, #T_d0d42_row9_col0, #T_d0d42_row11_col0, #T_d0d42_row11_col1, #T_d0d42_row11_col2, #T_d0d42_row11_col4, #T_d0d42_row12_col0, #T_d0d42_row12_col1, #T_d0d42_row12_col2, #T_d0d42_row12_col4, #T_d0d42_row13_col0, #T_d0d42_row13_col1, #T_d0d42_row13_col2, #T_d0d42_row13_col3, #T_d0d42_row13_col4, #T_d0d42_row13_col5, #T_d0d42_row14_col3, #T_d0d42_row14_col4, #T_d0d42_row15_col3, #T_d0d42_row15_col4, #T_d0d42_row16_col3, #T_d0d42_row16_col4, #T_d0d42_row17_col1, #T_d0d42_row17_col2, #T_d0d42_row17_col3, #T_d0d42_row17_col4, #T_d0d42_row17_col5, #T_d0d42_row18_col0, #T_d0d42_row18_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_d0d42_row0_col1, #T_d0d42_row0_col2, #T_d0d42_row0_col3, #T_d0d42_row1_col2, #T_d0d42_row1_col4, #T_d0d42_row2_col2, #T_d0d42_row2_col4, #T_d0d42_row3_col0, #T_d0d42_row3_col4, #T_d0d42_row4_col0, #T_d0d42_row4_col2, #T_d0d42_row4_col5, #T_d0d42_row5_col0, #T_d0d42_row5_col2, #T_d0d42_row6_col0, #T_d0d42_row6_col2, #T_d0d42_row6_col3, #T_d0d42_row7_col0, #T_d0d42_row7_col5, #T_d0d42_row8_col0, #T_d0d42_row8_col1, #T_d0d42_row8_col2, #T_d0d42_row8_col3, #T_d0d42_row8_col4, #T_d0d42_row8_col5, #T_d0d42_row9_col1, #T_d0d42_row9_col2, #T_d0d42_row9_col3, #T_d0d42_row9_col4, #T_d0d42_row9_col5, #T_d0d42_row10_col0, #T_d0d42_row10_col1, #T_d0d42_row10_col2, #T_d0d42_row10_col3, #T_d0d42_row10_col4, #T_d0d42_row10_col5, #T_d0d42_row11_col3, #T_d0d42_row11_col5, #T_d0d42_row12_col3, #T_d0d42_row12_col5, #T_d0d42_row14_col0, #T_d0d42_row14_col1, #T_d0d42_row14_col2, #T_d0d42_row14_col5, #T_d0d42_row15_col0, #T_d0d42_row15_col1, #T_d0d42_row15_col2, #T_d0d42_row15_col5, #T_d0d42_row16_col0, #T_d0d42_row16_col1, #T_d0d42_row16_col2, #T_d0d42_row16_col5, #T_d0d42_row17_col0, #T_d0d42_row18_col1, #T_d0d42_row18_col2, #T_d0d42_row18_col3, #T_d0d42_row18_col5 {
#   background-color: #fdbf71;
#   color: #000000;
# }
# #T_d0d42_row0_col5, #T_d0d42_row1_col0, #T_d0d42_row1_col1, #T_d0d42_row1_col5, #T_d0d42_row2_col0, #T_d0d42_row2_col1, #T_d0d42_row2_col5, #T_d0d42_row3_col1, #T_d0d42_row3_col2, #T_d0d42_row3_col3, #T_d0d42_row3_col5, #T_d0d42_row4_col1, #T_d0d42_row4_col3, #T_d0d42_row4_col4, #T_d0d42_row5_col3, #T_d0d42_row5_col4, #T_d0d42_row5_col5, #T_d0d42_row6_col1, #T_d0d42_row6_col4, #T_d0d42_row6_col5 {
#   background-color: #bde2ee;
#   color: #000000;
# }
# #T_d0d42_row1_col3, #T_d0d42_row2_col3, #T_d0d42_row5_col1 {
#   background-color: #313695;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d0d42">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0d42_level0_col0" class="col_heading level0 col0" >1.01x</th>
#       <th id="T_d0d42_level0_col1" class="col_heading level0 col1" >1.5x</th>
#       <th id="T_d0d42_level0_col2" class="col_heading level0 col2" >3x</th>
#       <th id="T_d0d42_level0_col3" class="col_heading level0 col3" >5x</th>
#       <th id="T_d0d42_level0_col4" class="col_heading level0 col4" >7x</th>
#       <th id="T_d0d42_level0_col5" class="col_heading level0 col5" >10x</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0d42_level0_row0" class="row_heading level0 row0" >v2</th>
#       <td id="T_d0d42_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_d0d42_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_d0d42_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_d0d42_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_d0d42_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_d0d42_row0_col5" class="data row0 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_d0d42_level0_row1" class="row_heading level0 row1" >v3</th>
#       <td id="T_d0d42_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_d0d42_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_d0d42_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_d0d42_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_d0d42_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_d0d42_row1_col5" class="data row1 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_d0d42_level0_row2" class="row_heading level0 row2" >v13</th>
#       <td id="T_d0d42_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_d0d42_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_d0d42_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_d0d42_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_d0d42_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_d0d42_row2_col5" class="data row2 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_d0d42_level0_row3" class="row_heading level0 row3" >v4</th>
#       <td id="T_d0d42_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_d0d42_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_d0d42_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_d0d42_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_d0d42_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_d0d42_row3_col5" class="data row3 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_d0d42_level0_row4" class="row_heading level0 row4" >v5</th>
#       <td id="T_d0d42_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_d0d42_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_d0d42_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_d0d42_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_d0d42_row4_col4" class="data row4 col4" >2</td>
#       <td id="T_d0d42_row4_col5" class="data row4 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d0d42_level0_row5" class="row_heading level0 row5" >v6</th>
#       <td id="T_d0d42_row5_col0" class="data row5 col0" >1</td>
#       <td id="T_d0d42_row5_col1" class="data row5 col1" >3</td>
#       <td id="T_d0d42_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_d0d42_row5_col3" class="data row5 col3" >2</td>
#       <td id="T_d0d42_row5_col4" class="data row5 col4" >2</td>
#       <td id="T_d0d42_row5_col5" class="data row5 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_d0d42_level0_row6" class="row_heading level0 row6" >v7</th>
#       <td id="T_d0d42_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_d0d42_row6_col1" class="data row6 col1" >2</td>
#       <td id="T_d0d42_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_d0d42_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_d0d42_row6_col4" class="data row6 col4" >2</td>
#       <td id="T_d0d42_row6_col5" class="data row6 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_d0d42_level0_row7" class="row_heading level0 row7" >v8</th>
#       <td id="T_d0d42_row7_col0" class="data row7 col0" >1</td>
#       <td id="T_d0d42_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_d0d42_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_d0d42_row7_col3" class="data row7 col3" >0</td>
#       <td id="T_d0d42_row7_col4" class="data row7 col4" >0</td>
#       <td id="T_d0d42_row7_col5" class="data row7 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d0d42_level0_row8" class="row_heading level0 row8" >v9</th>
#       <td id="T_d0d42_row8_col0" class="data row8 col0" >1</td>
#       <td id="T_d0d42_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_d0d42_row8_col2" class="data row8 col2" >1</td>
#       <td id="T_d0d42_row8_col3" class="data row8 col3" >1</td>
#       <td id="T_d0d42_row8_col4" class="data row8 col4" >1</td>
#       <td id="T_d0d42_row8_col5" class="data row8 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d0d42_level0_row9" class="row_heading level0 row9" >v10</th>
#       <td id="T_d0d42_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_d0d42_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_d0d42_row9_col2" class="data row9 col2" >1</td>
#       <td id="T_d0d42_row9_col3" class="data row9 col3" >1</td>
#       <td id="T_d0d42_row9_col4" class="data row9 col4" >1</td>
#       <td id="T_d0d42_row9_col5" class="data row9 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d0d42_level0_row10" class="row_heading

# %%
topThreeCheckdf.sum(axis=0)
# Out:
# 1.01x    15
# 1.5x     21
# 3x       15
# 5x       20
# 7x       12
# 10x      23
# dtype: int64
